# %% [markdown]
# <a href="https://colab.research.google.com/github/lukmannm/data-science-2026/blob/main/Pertemuan1_Lukman_240401010181.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # Pertemuan 1: Setup GitHub & Pengenalan Data Science
#
# - Nama: Lukman Nur Hakim
# - NIM: 240401010181
# - Kelas: IF401
# - Mata Kuliah: Data Science

# %% [markdown]
# ## Tujuan Pertemuan
#
# - Membuat akun GitHub dan repositori publik untuk menyimpan hasil praktikum
# - Mengenal tools utama yang digunakan dalam mata kuliah Data Science
# - Mengunggah notebook pertama ke repositori GitHub

# %%
# SEL 1: Output sederhana
print("Hello, Data Science!")
print("Selamat datang di mata kuliah Pengantar Data Science!")
# Out:
# Hello, Data Science!
# Selamat datang di mata kuliah Pengantar Data Science!

# %%
# SEL 2: Variabel dan tipe data dasar
nama = "Lukman Nur Hakim"   # String
angkatan = 2024              # Integer
ipk = 3.96                   # Float
aktif = True                 # Boolean

print(f"Nama    : {nama}")
print(f"Angkatan: {angkatan}")
print(f"IPK     : {ipk}")
print(f"Aktif   : {aktif}")
# Out:
# Nama    : Lukman Nur Hakim
# Angkatan: 2024
# IPK     : 3.96
# Aktif   : True

# %%
# SEL 3: List dan perulangan
tools = ["Python", "Google Colab", "Jupyter Notebook", "GitHub"]

print("\nTools Data Science yang akan kita pelajari:")
for i, tool in enumerate(tools, 1):
    print(f"  {i}. {tool}")
# Out:
# Tools Data Science yang akan kita pelajari:
#   1. Python
#   2. Google Colab
#   3. Jupyter Notebook
#   4. GitHub

# %%
# SEL 4: Fungsi sederhana
def perkenalan(nama, prodi, angkatan):
    """Fungsi untuk menampilkan perkenalan mahasiswa."""
    return f"Hai! Saya {nama} dari {prodi}, angkatan {angkatan}."

hasil = perkenalan("Lukman Nur Hakim", "Informatika", 2024)
print(hasil)

# %% [markdown]
# ## Kesimpulan
#
# Pertemuan ini mempelajari dasar-dasar Python seperti variabel, tipe data, list, perulangan, dan fungsi, sekaligus setup GitHub sebagai tempat menyimpan hasil praktikum. Notebook pertama berhasil dibuat dan diunggah ke repositori publik data-science-2026 yang dapat diakses oleh dosen maupun publik. Keterbatasan yang muncul adalah materi Python yang dibahas masih sangat dasar, namun menjadi fondasi penting sebelum masuk ke analisis data di pertemuan berikutnya.
